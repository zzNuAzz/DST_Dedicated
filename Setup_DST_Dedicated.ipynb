# %% [markdown]
# From here we can found a fast way to start a dedicated server from google colaboratory (free).
# The maximum runtime of the server at here is about 12 hours (or less).
#
# If you want to save states of the game, please download your cluster' folders normally on the left panel (Files).

# %% [markdown]
# You will read and run cell by cell to get more information and do some additional stuff (such as replace your server token, ...).
#
# In the furture, you totally can customize all things, that will be change server cluster, change seeds, auto save all file to google drive to save time (mount GD and change $PR_DIR to exactly location u want), add mods, ...

# %% [markdown]
# This tutorial is seperated to three pharse: initial, setup and run. If you first times take part in, please run step by step, else run all except all cell inside **SETUP** part.

# %% [markdown]
# ---
#
# **IMPORTANT**:
# You cant save ur modified code here, please save a copy to Drive before (or save a copy in Drive after).

# %% [markdown]
# # INITIAL

# %% [markdown]
# ## Original tutorial post (by klei 4rum)
#
# https://forums.kleientertainment.com/forums/topic/64441-dedicated-server-quick-setup-guide-linux/

# %%
# !curl ipinfo.io
# Out:
# {
#   "ip": "35.226.90.129",
#   "hostname": "129.90.226.35.bc.googleusercontent.com",
#   "city": "Council Bluffs",
#   "region": "Iowa",
#   "country": "US",
#   "loc": "41.2619,-95.8608",
#   "org": "AS15169 Google LLC",
#   "postal": "51502",
#   "timezone": "America/Chicago",
#   "readme": "https://ipinfo.io/missingauth"
# }

# %% [markdown]
# Deprecated: Make sure this machine support x86 environment (32bit)
# With the update Waterlogged, the game support 64bit as well.

# %% [markdown]
# ## Connect to working dir (can be located on google drive)

# %% [markdown]
# If you use Google Drive, please mount GD before run above cell (can be found mount button on the left `Files` panel)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# `PR_DIR` is a variable that hold the path to Server files. If you want auto save, please use a path to ur drive `ex: /content/drive/MyDrive/DST_dedi`, else keep default: `/content/`

# %%
#PR_DIR="/content/"
PR_DIR="/content/drive/MyDrive/DST_dedi"
INSTALL_TEMP_DIR="/content"
# %cd $INSTALL_TEMP_DIR
# Out:
# /content

# %% [markdown]
# ## install steamcmd

# %%
# !mkdir -p steamcmd
# %cd steamcmd
# Out:
# /content/steamcmd

# %%
# !wget "https://steamcdn-a.akamaihd.net/client/installer/steamcmd_linux.tar.gz"

# !tar -xvzf steamcmd_linux.tar.gz
# !rm steamcmd_linux.tar.gz

# !chmod -R 0755 *

# %cd $INSTALL_TEMP_DIR
# Out:
# --2021-09-09 07:40:13--  https://steamcdn-a.akamaihd.net/client/installer/steamcmd_linux.tar.gz
# Resolving steamcdn-a.akamaihd.net (steamcdn-a.akamaihd.net)... 23.54.76.12, 23.54.76.60
# Connecting to steamcdn-a.akamaihd.net (steamcdn-a.akamaihd.net)|23.54.76.12|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2428561 (2.3M) [application/octet-stream]
# Saving to: ‘steamcmd_linux.tar.gz’
#
# steamcmd_linux.tar. 100%[===================>]   2.32M  --.-KB/s    in 0.07s
#
# 2021-09-09 07:40:14 (35.1 MB/s) - ‘steamcmd_linux.tar.gz’ saved [2428561/2428561]
#
# steamcmd.sh
# linux32/steamcmd
# linux32/steamerrorreporter
# linux32/libstdc++.so.6
# linux32/crashhandler.so
# /content

# %% [markdown]
# # SETUP

# %% [markdown]
# Keep in mind that this section should run only one time if you set `PR_DIR` to Gdrive, or you want rewrite all server files.

# %% [markdown]
# ## Klei Server

# %%
# %cd $PR_DIR 
# !mkdir -p DoNotStarveTogether
# Out:
# /content/drive/MyDrive/DST_dedi

# %%
# %cd $PR_DIR/DoNotStarveTogether
# Out:
# /content/drive/MyDrive/DST_dedi/DoNotStarveTogether

# %%
# %cd $PR_DIR/DoNotStarveTogether
# !rm -rf * 
# !wget https://cdn.discordapp.com/attachments/817270986423664670/866591023400747058/MyDediServer.zip

# !unzip -q -o MyDediServer.zip
# !rm MyDediServer.zip

# !ls
# Out:
# /content/drive/MyDrive/DST_dedi/DoNotStarveTogether
# --2021-08-21 08:13:44--  https://cdn.discordapp.com/attachments/817270986423664670/866591023400747058/MyDediServer.zip
# Resolving cdn.discordapp.com (cdn.discordapp.com)... 162.159.130.233, 162.159.133.233, 162.159.135.233, ...
# Connecting to cdn.discordapp.com (cdn.discordapp.com)|162.159.130.233|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6157034 (5.9M) [application/zip]
# Saving to: ‘MyDediServer.zip’
#
# MyDediServer.zip    100%[===================>]   5.87M  --.-KB/s    in 0.1s
#
# 2021-08-21 08:13:44 (42.8 MB/s) - ‘MyDediServer.zip’ saved [6157034/6157034]
#
# MyDediServer

# %% [markdown]
# Please note that the name of dedicated server is `MyDediServer`, you need to rename again to make sure this match together.

# %% [markdown]
# Here is my demo secret token: ![demo token](https://cdn.discordapp.com/attachments/817270986423664670/866671332610801694/unknown.png)
#
# After that, please use your own `SECRET TOKEN` (can be gen from [Klei Server page](https://accounts.klei.com/account/game/servers?game=DontStarveTogether)) instead of default token, then replace your token here:

# %%
YOUR_TOKEN_PLS = "pds-g^KU_TNvAPMM0^uXboAMHYGCNxl14UKoiiL80U4R3/ItbUdoQBMvEJe+M="

assert YOUR_TOKEN_PLS != "PLEASE REPLACE ME INSIDE THE QUOTE"

# %% [markdown]
# **IMPORTANT**: Using your own secret token let you become admin of server (have a star next to player icon and can run [remote command](https://dontstarve.fandom.com/wiki/Console/Don%27t_Starve_Together_Commands)).

# %% [markdown]
# Make sure the previnous cell run complete, then followup:

# %%
with open('MyDediServer/cluster_token.txt', 'wt') as f:
        f.write(YOUR_TOKEN_PLS)

ur_saved_token = !cat MyDediServer/cluster_token.txt
print(ur_saved_token[0])

assert ur_saved_token[0] != "PLEASE REPLACE ME INSIDE THE QUOTE"
# Out:
# pds-g^KU_TNvAPMM0^uXboAMHYGCNxl14UKoiiL80U4R3/ItbUdoQBMvEJe+M=

# %% [markdown]
# ## Mods

# %%
# %cd $PR_DIR/DoNotStarveTogether
modoverrides = open("MyDediServer/Master/modoverrides.lua", "r").read()
import regex as re
id = re.compile(r'\"workshop-(\d+)\"')
mod_id = ' \n '.join(id.findall(modoverrides))
# Out:
# /content/drive/MyDrive/DST_dedi/DoNotStarveTogether

# %%
import regex as re
id = re.compile(r'(\d+)')

list_id = id.findall(mod_id)
list_id = list(filter(lambda x: x.strip() != "", list_id))
list_id = list(set(list_id))

# %%
# %cd $INSTALL_TEMP_DIR
# !mkdir -p dontstarvetogether_dedicated_server
# !mkdir -p dontstarvetogether_dedicated_server/mods
# %cd dontstarvetogether_dedicated_server/mods

nameregex = re.compile(r'<title>([\s\S]+)</title>')

import requests
with open('dedicated_server_mods_setup.lua', 'wt') as f:
    for index,id in enumerate(list_id):    
        text = requests.get(f"https://steamcommunity.com/sharedfiles/filedetails/?id={id}").text
        print(index+1,nameregex.findall(text)[0].replace('Steam Workshop::', ''))
        if "https://steamcommunity.com/workshop/browse/?section=collections&" in text:
            f.write(f"ServerModCollectionSetup(\"{id}\")\n")
        else:
            f.write(f"ServerModSetup(\"{id}\")\n")
# Out:
# /content
# /content/dontstarvetogether_dedicated_server/mods
# 1 [DST]Show Bundle
# 2 Campfire Respawn
# 3 Smart Minisign
# 4 Icebox Perish Settings (Global Update)
# 5 Fast Travel (GUI)
# 6 Moving Box
# 7 Extra Equip Slots
# 8 Global Positions
# 9 Global Pause
# 10 Show Me (Origin)
# 11 Better Ice Flingomatic [obsolete]
# 12 Epic Healthbar
# 13 Beefalo Status Bar
# 14 Extended Indicators WIP
# 15 Wormhole Icons [Server]
# 16 Simple Health Bar DST
# 17 [API] Gem Core(Now with World Seeds!)
# 18 Increased Stack size

# %% [markdown]
# # RUN

# %% [markdown]
# Copy server files to `.klei` folders.

# %%
# %cd ~

# !mkdir -p .klei
# !mkdir -p .klei/DoNotStarveTogether/

#!cp -r $PR_DIR/DoNotStarveTogether/* ~/.klei/DoNotStarveTogether
# !ln -sf $PR_DIR/DoNotStarveTogether/* ~/.klei/DoNotStarveTogether

# !ls $PR_DIR/DoNotStarveTogether/
# Out:
# /root
# MyDediServer

# %% [markdown]
# download auto script

# %%
# %cd $INSTALL_TEMP_DIR

# !git clone https://github.com/zzNuAzz/DST_Dedicated

# !cp DST_Dedicated/run_dedicated_servers.sh .
# Out:
# /content
# fatal: destination path 'DST_Dedicated' already exists and is not an empty directory.

# %% [markdown]
# Then just run this script, almost done.
#
# Please note that we need to download DST game (abount 2.3GB) when the first time run, and when you factory reset runtime.

# %%
# %cd $INSTALL_TEMP_DIR
# !chmod u+x run_dedicated_servers.sh
# !./run_dedicated_servers.sh $PR_DIR MyDediServer $INSTALL_TEMP_DIR
#!screen -S DSTServer -d -m ./run_dedicated_servers.sh $PR_DIR MyDediServer
# Out:
# /content
# Backup mods...
# Validating game...
# ERROR: ld.so: object '/usr/lib/x86_64-linux-gnu/libtcmalloc.so.4' from LD_PRELOAD cannot be preloaded (wrong ELF class: ELFCLASS64): ignored.
# Redirecting stderr to '/root/Steam/logs/stderr.txt'
# ILocalize::AddFile() failed to load file "public/steambootstrapper_english.txt".
# [  0%] Checking for available update...
# [----] Downloading update (0 of 53,943 KB)...
# [  0%] Downloading update (2,967 of 53,943 KB)...
# [  5%] Downloading update (6,489 of 53,943 KB)...
# [ 12%] Downloading update (8,978 of 53,943 KB)...
# [ 16%] Downloading update (11,715 of 53,943 KB)...
# [ 21%] Downloading update (14,204 of 53,943 KB)...
# [ 26%] Downloading update (16,692 of 53,943 KB)...
# [ 30%] Downloading update (19,182 of 53,943 KB)...
# [ 35%] Downloading update (21,669 of 53,943 KB)...
# [ 40%] Downloading update (24,155 of 53,943 KB)...
# [ 44%] Downloading update (26,893 of 53,943 KB)...
# [ 49%] Downloading update (29,382 of 53,943 KB)...
# [ 54%] Downloading update (31,871 of 53,943 KB)...
# [ 59%] Downloading update (34,359 of 53,943 KB)...
# [ 63%] Downloading update (36,217 of 53,943 KB)...
# [ 67%] Downloading update (37,461 of 53,943 KB)...
# [ 69%] Downloading update (38,705 of 53,943 KB)...
# [ 71%] Downloading update (39,950 of 53,943 KB)...
# [ 74%] Downloading update (41,331 of 53,943 KB)...
# [ 76%] Downloading update (42,576 of 53,943 KB)...
# [ 78%] Downloading update (43,820 of 53,943 KB)...
# [ 81%] Downloading update (45,186 of 53,943 KB)...
# [ 83%] Downloading update (46,430 of 53,943 KB)...
# [ 86%] Downloading update (47,675 of 53,943 KB)...
# [ 88%] Downloading update (48,919 of 53,943 KB)...
# [ 90%] Downloading update (50,288 of 53,943 KB)...
# [ 93%] Downloading update (51,532 of 53,943 KB)...
# [ 95%] Downloading update (52,777 of 53,943 KB)...
# [ 97%] Downloading update (53,943 of 53,943 KB)...
# [100%] Downloading update (53,943 of 53,943 KB)...
# [100%] Download Complete.
# [----] Applying update...
# [----] Extracting package...
# [----] Extracting package...
# [----] Extracting package...
# [----] Extracting package...
# [----] Installing update...
# [----] Installing update...
# [----] Installing update...
# [----] Installing update...
# [----] Installing update...
# [----] Installing update...
# [----] Installing update...
# [----] Installing update...
# [----] Cleaning up...
# [----] Update complete, launching...
# ERROR: ld.so: object '/usr/lib/x86_64-linux-gnu/libtcmalloc.so.4' from LD_PRELOAD cannot be preloaded (wrong ELF class: ELFCLASS64): ignored.
# Redirecting stderr to '/root/Steam/logs/stderr.txt'
# /tmp/dumps insufficient permissions - delete and recreate
# [  0%] Checking for available updates...
# [----] Verifying installation...
# [  0%] Downloading update...
# [  0%] Checking for available updates...
# [----] Download complete.
# [----] Extracting package...
# [----] Extracting package...
# [----] Extracting package...
# [----] Extracting package...
# [----] Installing update...
# [----] Installing update...
# [----] Installing update...
# [----] Installing update...
# [----] Installing update...
# [----] Installing update...
# [----] Installing update...
# [----] Installing update...
# [----] Cleaning up...
# [----] Update complete, launching Steamcmd...
# ERROR: ld.so: object '/usr/lib/x86_64-linux-gnu/libtcmalloc.so.4' from LD_PRELOAD cannot be preloaded (wrong ELF class: ELFCLASS64): ignored.
# Redirecting stderr to '/root/Steam/logs/stderr.txt'
# [  0%] Checking for available updates...
# [----] Verifying installation...
# Steam Console Client (c) Valve Corporation
# -- type 'quit' to exit --
# Loading Steam API...OK
#
# Connecting anonymously to Steam Public...OK
# Waiting for client config...OK
# Waiting for user info...OK
#  Update state (0x3) reconfiguring, progress: 0.00 (0 / 0)
#  Update state (0x5) verifying install, progress: 6.15 (151518369 / 2461784645)
#  Update state (0x11) preallocating, progress: 17.80 (438198560 / 2461784645)
#  Update state (0x61) downloading, progress: 0.00 (0 / 2461784645)
# Warning: failed to init SDL thread priority manager: SDL not found
#  Update state (0x61) downloading, progress: 2.20 (54111141 / 2461784645)
#  Update state (0x61) downloading, progress: 3.86 (94965945 / 2461784645)
#  Update state (0x61) downloading, progress: 5.43 (133722425 / 2461784645)
#  Update state (0x61) downloading, progress: 6.55 (161293201 / 2461784645)
#  Update state (0x61) downloading, progress: 7.11 (175022759 / 2461784645)
#  Update state (0x61) downloading, progress: 7.75 (190879364 / 2461784645)
#  Update state (0x61) downloading, progress: 8.41 (207158177 / 2461784645)
#  Update state (0x61) downloading, progress: 9.13 (224862368 / 2461784645)
#  Update state (0x61) downloading, progress: 9.85 (242407343 / 2461784645)
#  Update state (0x61) downloading, progress: 10.65 (262140833 / 2461784645)
#  Update state (0x61) downloading, progress: 11.39 (280344251 / 2461784645)
#  Update state (0x61) downloading, progress: 12.14 (298753596 / 2461784645)
#  Update state (0x61) downloading, progress: 12.92 (318013234 / 2461784645)
#  Update state (0x61) downloading, progress: 13.66 (336308712 / 2461784645)
#  Update state (0x61) downloading, progress: 14.42 (354954308 / 2461784645)
#  Update state (0x61) downloading, progress: 15.14 (372822304 / 2461784645)
#  Update state (0x61) downloading, progress: 15.87 (390596171 / 2461784645)
#  Update state (0x61) downloading, progress: 16.64 (409714339 / 2461784645)
#  Update state (0x61) downloading, progress: 17.41 (428509906 / 2461784645)
#  Update state (0x61) downloading, progress: 18.14 (446480056 / 2461784645)
#  Update state (0x61) downloading, progress: 18.90 (465273796 / 2461784645)
#  Update state (0x61) downloading, progress: 19.65 (483714711 / 2461784645)
#  Update state (0x61) downloading, progress: 20.44 (503132964 / 2461784645)
#  Update state (0x61) downloading, progress: 21.17 (521053213 / 2461784645)
#  Update state (0x61) downloading, progress: 22.67 (557972137 / 2461784645)
#  Update state (0x61) downloading, progress: 24.48 (602752886 / 2461784645)
#  Update state (0x61) downloading, progress: 25.70 (632674098 / 2461784645)
#  Update state (0x61) downloading, progress: 27.93 (687691303 / 2461784645)
#  Update state (0x61) downloading, progress: 29.76 (732735825 / 2461784645)
#  Update state (0x61) downloading, progress: 31.24 (769051617 / 2461784645)
#  Update state (0x61) downloading, progress: 32.54 (801142903 / 2461784645)
#  Update state (0x61) downloading, progress: 34.56 (850806686 / 2461784645)
#  Update state (0x61) downloading, progress: 35.34 (870043430 / 2461784645)
#  Update state (0x61) downloading, progress: 36.13 (889523027 / 2461784645)
#  Update state (0x61) downloading, progress: 36.92 (908881154 / 2461784645)
#  Update state (0x61) downloading, progress: 37.69 (927802268 / 2461784645)
#  Update state (0x61) downloading, progress: 38.42 (945715254 / 2461784645)
#  Update state (0x61) downloading, progress: 39.18 (964417554 / 2461784645)
#  Update state (0x61) downloading, progress: 39.94 (983157510 / 2461784645)
#  Update state (0x61) downloading, progress: 40.67 (1001158200 / 2461784645)
#  Update state (0x61) downloading, progress: 41.47 (1020822744 / 2461784645)
#  Update state (0x61) downloading, progress: 42.22 (1039431605 / 2461784645)
#  Update state (0x61) downloading, progress: 43.44 (1069507670 / 2461784645)
#  Update state (0x61) downloading, progress: 45.37 (1116819278 / 2461784645)
#  Update state (0x61) downloading, progress: 47.27 (1163624943 / 2461784645)
#  Update state (0x61) downloading, progress: 49.07 (1208013135 / 2461784645)
#  Update state (0x61) downloading, progress: 51.28 (1262444026 / 2461784645)
#  Update state (0x61) downloading, progress: 53.56 (1318471049 / 2461784645)
#  Update state (0x61) downloading, progress: 55.22 (1359340395 / 2461784645)
#  Update state (0x61) downloading, progress: 56.05 (1379830998 / 2461784645)
#  Update state (0x61) downloading, progress: 56.81 (1398600363 / 2461784645)
#  Update state (0x61) downloading, progress: 57.66 (1419430630 / 2461784645)
#  Update state (0x61) downloading, progress: 58.62 (1443141014 / 2461784645)
#  Update state (0x61) downloading, progress: 59.35 (1460998166 / 2461784645)
#  Update state (0x61) downloading, progress: 60.15 (1480735030 / 2461784645)
#  Update state (0x61) downloading, progress: 60.90 (1499269768 / 2461784645)
#  Update state (0x61) downloading, progress: 61.64 (1517491720 / 2461784645)
#  Update state (0x61) downloading, progress: 62.42 (1536543848 / 2461784645)
#  Update state (0x61) downloading, progress: 63.21 (1556039338 / 2461784645)
#  Update state (0x61) downloading, progress: 64.02 (1576148582 / 2461784645)
#  Update state (0x61) downloading, progress: 64.83 (1595953223 / 2461784645)
#  Update state (0x61) downloading, progress: 65.66 (1616363508 / 2461784645)
#  Update state (0x61) downloading, progress: 67.17 (1653655725 / 2461784645)
#  Update state (0x61) downloading, progress: 69.69 (1715669623 / 2461784645)
#  Update state (0x61) downloading, progress: 71.91 (1770308400 / 2461784645)
#  Update state (0x61) downloading, progress: 73.24 (1802888736 / 2461784645)
#  Update state (0x61) downloading, progress: 74.06 (1823248914 / 2461784645)
#  Update state (0x61) downloading, progress: 74.90 (1843990802 / 2461784645)
#  Update state (0x61) downloading, progress: 75.76 (1864962962 / 2461784645)
#  Update state (0x61) downloading, progress: 76.57 (1884892146 / 2461784645)
#  Update state (0x61) downloading, progress: 77.43 (1906088128 / 2461784645)
#  Update state (0x61) downloading, progress: 78.24 (1926129248 / 2461784645)
#  Update state (0x61) downloading, progress: 79.12 (1947689829 / 2461784645)
#  Update state (0x61) downloading, progress: 80.22 (1974850404 / 2461784645)
#  Update state (0x61) downloading, progress: 81.87 (2015505853 / 2461784645)
#  Update state (0x61) downloading, progress: 84.63 (2083322970 / 2461784645)
#  Update state (0x61) downloading, progress: 86.74 (2135260473 / 2461784645)
#  Update state (0x61) downloading, progress: 87.64 (2157515992 / 2461784645)
#  Update state (0x61) downloading, progress: 89.18 (2195304348 / 2461784645)
#  Update state (0x61) downloading, progress: 90.52 (2228446362 / 2461784645)
#  Update state (0x61) downloading, progress: 91.55 (2253703513 / 2461784645)
#  Update state (0x61) downloading, progress: 92.41 (2274837362 / 2461784645)
#  Update state (0x61) downloading, progress: 93.47 (2300971446 / 2461784645)
#  Update state (0x61) downloading, progress: 95.88 (2360350502 / 2461784645)
#  Update state (0x61) downloading, progress: 96.68 (2379986380 / 2461784645)
#  Update state (0x61) downloading, progress: 97.51 (2400552332 / 2461784645)
#  Update state (0x61) downloading, progress: 98.37 (2421767724 / 2461784645)
#  Update state (0x61) downloading, progress: 99.18 (2441538028 / 2461784645)
#  Update state (0x81) verifying update, progress: 0.09 (2097152 / 2461784645)
#  Update state (0x81) verifying update, progress: 6.48 (159437265 / 2461784645)
#  Update state (0x81) verifying update, progress: 25.31 (623010011 / 2461784645)
#  Update state (0x81) verifying update, progress: 43.88 (1080164606 / 2461784645)
#  Update state (0x81) verifying update, progress: 56.26 (1385031979 / 2461784645)
#  Update state (0x81) verifying update, progress: 68.71 (1691443903 / 2461784645)
#  Update state (0x81) verifying update, progress: 85.70 (2109841794 / 2461784645)
#  Update state (0x101) committing, progress: 17.13 (421655060 / 2461784645)
#  Update state (0x101) committing, progress: 68.32 (1681957595 / 2461784645)
# Success! App '343050' fully installed.
# Restore mods
# Caves:  [00:00:01]: PersistRootStorage is now /root/.klei//DoNotStarveTogether/MyDediServer/Caves/
# Caves:  [00:00:01]: Starting Up
# Caves:  [00:00:01]: Version: 475914
# Caves:  [00:00:01]: Current time: Thu Sep  9 07:51:47 2021
# Caves:
# Caves:  [00:00:01]: System Name: Linux
# Caves:  [00:00:01]: Host Name: 6932f6e42cac
# Master: [00:00:01]: PersistRootStorage is now /root/.klei//DoNotStarveTogether/MyDediServer/Master/
# Caves:  [00:00:01]: Release(Kernel) Version: 5.4.104+
# Master: [00:00:01]: Starting Up
# Caves:  [00:00:01]: Kernel Build Timestamp: #1 SMP Sat Jun 5 09:50:34 PDT 2021
# Master: [00:00:01]: Version: 475914
# Caves:  [00:00:01]: Machine Arch: x86_64
# Master: [00:00:01]: Current time: Thu Sep  9 07:51:47 2021
# Master:
# Caves:  [00:00:01]: Don't Starve Together: 475914 LINUX
# Master: [00:00:01]: System Name: Linux
# Caves:  [00:00:01]: Build Date: 168
# Master: [00:00:01]: Host Name: 6932f6e42cac
# Caves:  [00:00:01]: Mode: 64-bit
# Master: [00:00:01]: Release(Kernel) Version: 5.4.104+
# Caves:  [00:00:01]: Parsing command line
# Master: [00:00:01]: Kernel Build Timestamp: #1 SMP Sat Jun 5 09:50:34 PDT 2021
# Caves:  [00:00:01]: Command Line Arguments: -console -cluster MyDediServer -monitor_parent_process 395 -shard Caves
# Master: [00:00:01]: Machine Arch: x86_64
# Caves:  [00:00:01]: [WARNING] -console has been deprecated: Use the [MISC] / console_enabled setting instead.
# Master: [00:00:01]: Don't Starve Together: 475914 LINUX
# Caves:  [00:00:01]: Initializing distribution platform
# Master: [00:00:01]: Build Date: 168
# Caves:  [00:00:01]: ....Done
# Master: [00:00:01]: Mode: 64-bit
# Master: [00:00:01]: Parsing command line
# Caves:  [00:00:01]: THREAD - started 'GAClient' (139916214363904)
# Master: [00:00:01]: Command Line Arguments: -console -cluster MyDediServer -monitor_parent_process 395 -shard Master
# Caves:  [00:00:01]: CurlRequestManager::ClientThread::Main()
# Caves:  [00:00:01]: Mounting file system databundles/klump.zip successful.
# Master: [00:00:01]: [WARNING] -console has been deprecated: Use the [MISC] / console_enabled setting instead.
# Master: [00:00:01]: Initializing distribution platform
# Caves:  [00:00:01]: Mounting file system databundles/shaders.zip successful.
# Master: [00:00:01]: ....Done
# Master: [00:00:01]: THREAD - started 'GAClient' (140668522841856)
# Master: [00:00:01]: CurlRequestManager::ClientThread::Main()
# Master: [00:00:01]: Mounting file system databundles/klump.zip successful.
# Caves:  [00:00:01]: Mounting file system databundles/fonts.zip successful.
# Master: [00:00:01]: Mounting file system databundles/shaders.zip successful.
# Master: [00:00:01]: Mounting file system databundles/fonts.zip successful.
# Master: [00:00:01]: Mounting file system databundles/anim_dynamic.zip successful.
# Caves:  [00:00:01]: Mounting file system databundles/anim_dynamic.zip successful.
# Caves:  [00:00:01]: Mounting file system databundles/bigportraits.zip successful.
# Master: [00:00:01]: Mounting file system databundles/bigportraits.zip successful.
# Master: [00:00:01]: Mounting file system databundles/images.zip successful.
# Caves:  [00:00:01]: Mounting file system databundles/images.zip successful.
# Caves:  [00:00:01]: Mounting file system databundles/scripts.zip successful.
# Master: [00:00:01]: Mounting file system databundles/scripts.zip successful.
# Master: [00:00:01]: [Steam] SteamGameServer_Init(10999, 27016)
# Caves:  [00:00:01]: [Steam] SteamGameServer_Init(10998, 27017)
# [S_API] SteamAPI_Init(): Loaded local 'steamclient.so' OK.
# [S_API] SteamAPI_Init(): Loaded local 'steamclient.so' OK.
# CAppInfoCacheReadFromDiskThread took 48 milliseconds to initialize
# CAppInfoCacheReadFromDiskThread took 48 milliseconds to initialize
# CApplicationManagerPopulateThread took 0 milliseconds to initialize (will have waited on CAppInfoCacheReadFromDiskThread)
# CApplicationManagerPopulateThread took 1 milliseconds to initialize (will have waited on CAppInfoCacheReadFromDiskThread)
# RecordSteamInterfaceCreation (PID 470): SteamGameServer013 /
# RecordSteamInterfaceCreation (PID 470): SteamUtils010 /
# Setting breakpad minidump AppID = 322330
# Master: [00:00:02]: [Steam] SteamGameServer_Init success
# RecordSteamInterfaceCreation (PID 468): SteamGameServer013 /
# RecordSteamInterfaceCreation (PID 470): SteamGameServer013 /
# RecordSteamInterfaceCreation (PID 468): SteamUtils010 /
# Setting breakpad minidump AppID = 322330
# Caves:  [00:00:02]: [Steam] SteamGameServer_Init success
# RecordSteamInterfaceCreation (PID 468): SteamGameServer013 /
# RecordSteamInterfaceCreation (PID 470): STEAMUGC_INTERFACE_VERSION015 /
# RecordSteamInterfaceCreation (PID 468): STEAMUGC_INTERFACE_VERSION015 /
# Master: [00:00:02]: ProfileIndex:4.48
# Caves:  [00:00:02]: ProfileIndex:4.85
# Master: [00:00:02]: [Connect] PendingConnection::Reset(true)
# Caves:  [00:00:02]: [Connect] PendingConnection::Reset(true)
# Caves:  [00:00:02]: Platform: 1
# Master: [00:00:02]: Platform: 1
# Caves:  [00:00:02]: THREAD - started 'Ping Job Thread' (139916158613248)
# Master: [00:00:02]: Network tick rate: U=15(2), D=0
# Caves:  [00:00:02]: Network tick rate: U=15(2), D=0
# Master: [00:00:02]: Network tick rate: U=15(2), D=0
# Caves:  [00:00:02]: Network tick rate: U=15(2), D=0
# Master: [00:00:02]: THREAD - started 'Ping Job Thread' (140668467091200)
# Master: [00:00:02]: THREAD - started 'StreamInput' (140668463937280)
# Master: [00:00:02]: OnLoadPermissionList: /root/.klei//DoNotStarveTogether/MyDediServer/blocklist.txt (Failure)
# Master: [00:00:02]: OnLoadPermissionList: /root/.klei//DoNotStarveTogether/MyDediServer/adminlist.txt (Failure)
# Master: [00:00:02]: OnLoadUserIdList: /root/.klei//DoNotStarveTogether/MyDediServer/whitelist.txt (Failure)
# Master: [00:00:02]: Token retrieved from: /root/.klei//DoNotStarveTogether/MyDediServer/cluster_token.txt
# Master: [00:00:02]: Token retrieved from: /root/.klei//DoNotStarveTogether/MyDediServer/cluster_token.txt
# Master: [00:00:02]: cGame::InitializeOnMainThread
# Master: [00:00:02]: Renderer initialize: Okay
# Master: [00:00:02]: AnimManager initialize: Okay
# Master: [00:00:02]: Buffers initialize: Okay
# Master: [00:00:02]: cDontStarveGame::DoGameSpecificInitialize()
# Master: [00:00:02]: GameSpecific initialize: Okay
# Master: [00:00:02]: cGame::StartPlaying
# Master: [00:00:02]: AppVersion::GetArchitecture() x64
# Master: [00:00:02]: LOADING LUA
# Master: [00:00:02]: DoLuaFile scripts/main.lua
# Master: [00:00:02]: DoLuaFile loading buffer scripts/main.lua
# Caves:  [00:00:02]: THREAD - started 'StreamInput' (139916155459328)
# Caves:  [00:00:02]: OnLoadPermissionList: /root/.klei//DoNotStarveTogether/MyDediServer/blocklist.txt (Failure)
# Caves:  [00:00:02]: OnLoadPermissionList: /root/.klei//DoNotStarveTogether/MyDediServer/adminlist.txt (Failure)
# Caves:  [00:00:02]: OnLoadUserIdList: /root/.klei//DoNotStarveTogether/MyDediServer/whitelist.txt (Failure)
# Caves:  [00:00:02]: Token retrieved from: /root/.klei//DoNotStarveTogether/MyDediServer/cluster_token.txt
# Caves:  [00:00:02]: Token retrieved from: /root/.klei//DoNotStarveTogether/MyDediServer/cluster_token.txt
# Caves:  [00:00:02]: cGame::InitializeOnMainThread
# Caves:  [00:00:02]: Renderer initialize: Okay
# Caves:  [00:00:02]: AnimManager initialize: Okay
# Caves:  [00:00:02]: Buffers initialize: Okay
# Caves:  [00:00:02]: cDontStarveGame::DoGameSpecificInitialize()
# Caves:  [00:00:02]: GameSpecific initialize: Okay
# Caves:  [00:00:02]: cGame::StartPlaying
# Caves:  [00:00:02]: AppVersion::GetArchitecture() x64
# Caves:  [00:00:02]: LOADING LUA
# Caves:  [00:00:02]: DoLuaFile scripts/main.lua
# Caves:  [00:00:02]: DoLuaFile loading buffer scripts/main.lua
# Master: [00:00:03]:   taskgrouplist:	default	Together
# Master: [00:00:03]:   taskgrouplist:	classic	Classic
# Master: [00:00:03]:   taskgrouplist:	cave_default	Underground
# Master: [00:00:03]:   taskgrouplist:	lavaarena_taskset	The Forge
# Master: [00:00:03]:   taskgrouplist:	quagmire_taskset	The Gorge
# Master: [00:00:03]: running main.lua
# Master:
# Caves:  [00:00:03]:   taskgrouplist:	default	Together
# Caves:  [00:00:03]:   taskgrouplist:	classic	Classic
# Caves:  [00:00:03]:   taskgrouplist:	cave_default	Underground
# Caves:  [00:00:03]:   taskgrouplist:	lavaarena_taskset	The Forge
# Caves:  [00:00:03]:   taskgrouplist:	quagmire_taskset	The Gorge
# Caves:  [00:00:03]: running main.lua
# Caves:
# Master: [00:00:03]: loaded modindex
# Master: [00:00:03]: ModIndex: Beginning normal load sequence for dedicated server.
# Master:
# Caves:  [00:00:03]: loaded modindex
# Caves:  [00:00:03]: ModIndex: Beginning normal load sequence for dedicated server.
# Caves:
# Master: [00:00:04]: DownloadPublishedFile [0] 2115943953
# Master: [00:00:04]: DownloadPublishedFile [0] 1530801499
# Master: [00:00:04]: DownloadPublishedFile [0] 378160973
# Master: [00:00:04]: DownloadPublishedFile [0] 374550642
# Master: [00:00:04]: DownloadPublishedFile [0] 380423963
# Master: [00:00:04]: DownloadPublishedFile [0] 2229630615
# Master: [00:00:04]: DownloadPublishedFile [0] 700236083
# Master: [00:00:04]: DownloadPublishedFile [0] 666155465
# Master: [00:00:04]: DownloadPublishedFile [0] 1207269058
# Master: [00:00:04]: DownloadPublishedFile [0] 1595631294
# Master: [00:00:04]: DownloadPublishedFile [0] 1271089343
# Master: [00:00:04]: DownloadPublishedFile [0] 1172839635
# Master: [00:00:04]: DownloadPublishedFile [0] 375850593
# Master: [00:00:04]: DownloadPublishedFile [0] 1505270912
# Master: [00:00:04]: DownloadPublishedFile [0] 336882447
# Master: [00:00:04]: DownloadPublishedFile [0] 344071294
# Master: [00:00:04]: DownloadPublishedFile [0] 346479579
# Master: [00:00:04]: DownloadPublishedFile [0] 350811795
# Master: [00:00:04]: DownloadPublishedFile [0] 353875384
# Master: [00:00:04]: DownloadPublishedFile [0] 361336115
# Caves:  [00:00:04]: DownloadPublishedFile [0] 2115943953
# Caves:  [00:00:04]: DownloadPublishedFile [0] 1530801499
# Caves:  [00:00:04]: DownloadPublishedFile [0] 378160973
# Caves:  [00:00:04]: DownloadPublishedFile [0] 374550642
# Caves:  [00:00:04]: DownloadPublishedFile [0] 380423963
# Caves:  [00:00:04]: DownloadPublishedFile [0] 2229630615
# Caves:  [00:00:04]: DownloadPublishedFile [0] 700236083
# Caves:  [00:00:04]: DownloadPublishedFile [0] 666155465
# Caves:  [00:00:04]: DownloadPublishedFile [0] 1207269058
# Caves:  [00:00:04]: DownloadPublishedFile [0] 1595631294
# Caves:  [00:00:04]: DownloadPublishedFile [0] 1271089343
# Caves:  [00:00:04]: DownloadPublishedFile [0] 1172839635
# Caves:  [00:00:04]: DownloadPublishedFile [0] 375850593
# Caves:  [00:00:04]: DownloadPublishedFile [0] 1505270912
# Caves:  [00:00:04]: DownloadPublishedFile [0] 336882447
# Caves:  [00:00:04]: DownloadPublishedFile [0] 344071294
# Caves:  [00:00:04]: DownloadPublishedFile [0] 346479579
# Caves:  [00:00:04]: DownloadPublishedFile [0] 350811795
# Caves:  [00:00:04]: DownloadPublishedFile [0] 353875384
# Caves:  [00:00:04]: DownloadPublishedFile [0] 361336115
# Master: [00:00:04]: OnDownloadPublishedFile [1] 2115943953
# Master: [00:00:04]: Could not open directory [../mods/workshop-2115943953] 2 (/content/dontstarvetogether_dedicated_server/data)
# Master: [00:00:04]: cWorkshopMod::UnzipMod ../mods/workshop-2115943953
# Caves:  [00:00:05]: OnDownloadPublishedFile [1] 2115943953
# Caves:  [00:00:05]: ... File [modmain.lua]
# Caves:  [00:00:05]: ... File [modicon.xml]
# Caves:  [00:00:05]: ... File [modinfo.lua]
# Caves:  [00:00:05]: ... File [modicon.tex]
# Caves:  [00:00:05]: DelDirectory [../mods/workshop-2115943953] 0: ok.
# Caves:  [00:00:05]: cWorkshopMod::UnzipMod ../mods/workshop-2115943953
# Master: [00:00:05]: OnDownloadPublishedFile [1] 1530801499
# Master: [00:00:05]: Could not open directory [../mods/workshop-1530801499] 2 (/content/dontstarvetogether_dedicated_server/data)
# Master: [00:00:05]: cWorkshopMod::UnzipMod ../mods/workshop-1530801499
# Caves:  [00:00:05]: OnDownloadPublishedFile [1] 1530801499
# Caves:  [00:00:05]: ... File [modmain.lua]
# Caves:  [00:00:05]: ... File [modicon.xml]
# Caves:  [00:00:05]: ... File [modinfo.lua]
# Caves:  [00:00:05]: ... File [modicon.tex]
# Caves:  [00:00:05]: ... Directory [scripts]
# Caves:  [00:00:05]: ... Directory [prefabs]
# Caves:  [00:00:05]: ... Directory [components]
# Caves:  [00:00:05]: ... Directory [screens]
# Caves:  [00:00:05]: ... File [travelable_classified.lua]
# Caves:  [00:00:05]: DelDirectory [../mods/workshop-1530801499/scripts/prefabs] 0: ok.
# Caves:  [00:00:05]: ... File [travelable.lua]
# Caves:  [00:00:05]: ... File [travelable_replica.lua]
# Caves:  [00:00:05]: DelDirectory [../mods/workshop-1530801499/scripts/components] 0: ok.
# Caves:  [00:00:05]: ... File [travelscreen.lua]
# Caves:  [00:00:05]: DelDirectory [../mods/workshop-1530801499/scripts/screens] 0: ok.
# Caves:  [00:00:05]: DelDirectory [../mods/workshop-1530801499/scripts] 0: ok.
# Caves:  [00:00:05]: DelDirectory [../mods/workshop-1530801499] 0: ok.
# Caves:  [00:00:05]: cWorkshopMod::UnzipMod ../mods/workshop-1530801499
# Master: [00:00:05]: OnDownloadPublishedFile [1] 378160973
# Master: [00:00:05]: Could not open directory [../mods/workshop-378160973] 2 (/content/dontstarvetogether_dedicated_server/data)
# Master: [00:00:05]: cWorkshopMod::UnzipMod ../mods/workshop-378160973
# Caves:  [00:00:05]: OnDownloadPublishedFile [1] 378160973
# Caves:  [00:00:05]: ... File [modmain.lua]
# Caves:  [00:00:05]: ... File [GlobalPositionsIcon.tex]
# Caves:  [00:00:05]: ... File [modinfo.lua]
# Caves:  [00:00:05]: ... Directory [scripts]
# Caves:  [00:00:05]: ... File [GlobalPositionsIcon.xml]
# Caves:  [00:00:05]: ... Directory [minimap]
# Caves:  [00:00:05]: ... Directory [images]
# Caves:  [00:00:05]: ... Directory [prefabs]
# Caves:  [00:00:05]: ... Directory [components]
# Caves:  [00:00:05]: ... Directory [widgets]
# Caves:  [00:00:05]: ... File [worldmapexplorer.lua]
# Caves:  [00:00:05]: ... File [globalmapicon_noproxy.lua]
# Caves:  [00:00:05]: ... File [globalposition_classified.lua]
# Caves:  [00:00:05]: ... File [smoketrail.lua]
# Caves:  [00:00:05]: ... File [pings.lua]
# Caves:  [00:00:05]: DelDirectory [../mods/workshop-378160973/scripts/prefabs] 0: ok.
# Caves:  [00:00:05]: ... File [smokeemitter.lua]
# Caves:  [00:00:05]: ... File [globalposition.lua]
# Caves:  [00:00:05]: ... File [globalpositions.lua]
# Caves:  [00:00:05]: DelDirectory [../mods/workshop-378160973/scripts/components] 0: ok.
# Caves:  [00:00:05]: ... File [pingbadge.lua]
# Caves:  [00:00:05]: ... File [pingwheel.lua]
# Caves:  [00:00:05]: ... File [maphoverer.lua]
# Caves:  [00:00:05]: DelDirectory [../mods/workshop-378160973/scripts/widgets] 0: ok.
# Caves:  [00:00:05]: DelDirectory [../mods/workshop-378160973/scripts] 0: ok.
# Caves:  [00:00:05]: ... File [ping_gohere.xml]
# Caves:  [00:00:05]: ... File [campfire.xml]
# Caves:  [00:00:05]: ... File [ping_danger.xml]
# Caves:  [00:00:05]: ... File [ping_danger.tex]
# Caves:  [00:00:05]: ... File [ping_explore.xml]
# Caves:  [00:00:05]: ... File [ping_omw.tex]
# Caves:  [00:00:05]: ... File [ping_generic.tex]
# Caves:  [00:00:05]: ... File [ping_generic.xml]
# Caves:  [00:00:05]: ... File [campfire.tex]
# Caves:  [00:00:05]: ... File [ping_omw.xml]
# Caves:  [00:00:05]: ... File [ping_gohere.tex]
# Caves:  [00:00:05]: ... File [ping_explore.tex]
# Caves:  [00:00:05]: DelDirectory [../mods/workshop-378160973/minimap] 0: ok.
# Caves:  [00:00:05]: ... File [sharelocation.xml]
# Caves:  [00:00:05]: ... File [PingExplore.tex]
# Caves:  [00:00:05]: ... File [PingOmw.xml]
# Caves:  [00:00:05]: ... File [PingClear.tex]
# Caves:  [00:00:05]: ... File [PingCancel.xml]
# Caves:  [00:00:05]: ... File [PingDanger.tex]
# Caves:  [00:00:05]: ... File [PingDelete.tex]
# Caves:  [00:00:05]: ... File [PingGoHere.tex]
# Caves:  [00:00:05]: ... File [unsharelocation.tex]
# Caves:  [00:00:05]: ... File [PingGoHere.xml]
# Caves:  [00:00:05]: ... File [PingDelete.xml]
# Caves:  [00:00:05]: ... File [PingDanger.xml]
# Caves:  [00:00:05]: ... File [sharelocation.tex]
# Caves:  [00:00:05]: ... File [PingClear.xml]
# Caves:  [00:00:05]: ... File [PingCancel.tex]
# Caves:  [00:00:05]: ... File [PingExplore.xml]
# Caves:  [00:00:05]: ... File [unsharelocation.xml]
# Caves:  [00:00:05]: ... File [Ping.xml]
# Caves:  [00:00:05]: ... File [Ping.tex]
# Caves:  [00:00:05]: ... File [status_bg.xml]
# Caves:  [00:00:05]: ... File [status_bg.tex]
# Caves:  [00:00:05]: ... File [PingOmw.tex]
# Caves:  [00:00:05]: DelDirectory [../mods/workshop-378160973/images] 0: ok.
# Caves:  [00:00:05]: DelDirectory [../mods/workshop-378160973] 0: ok.
# Caves:  [00:00:05]: cWorkshopMod::UnzipMod ../mods/workshop-378160973
# Master: [00:00:06]: OnDownloadPublishedFile [1] 374550642
# Master: [00:00:06]: Could not open directory [../mods/workshop-374550642] 2 (/content/dontstarvetogether_dedicated_server/data)
# Master: [00:00:06]: cWorkshopMod::UnzipMod ../mods/workshop-374550642
# Caves:  [00:00:06]: OnDownloadPublishedFile [1] 374550642
# Caves:  [00:00:06]: ... File [modmain.lua]
# Caves:  [00:00:06]: ... File [stack.PNG]
# Caves:  [00:00:06]: ... File [modinfo.lua]
# Caves:  [00:00:06]: DelDirectory [../mods/workshop-374550642] 0: ok.
# Caves:  [00:00:06]: cWorkshopMod::UnzipMod ../mods/workshop-374550642
# Caves:  [00:00:06]: OnDownloadPublishedFile [1] 380423963
# Caves:  [00:00:06]: Could not open directory [../mods/workshop-380423963] 2 (/content/dontstarvetogether_dedicated_server/data)
# Caves:  [00:00:06]: cWorkshopMod::UnzipMod ../mods/workshop-380423963
# Master: [00:00:06]: OnDownloadPublishedFile [1] 380423963
# Master: [00:00:06]: ... File [modmain.lua]
# Master: [00:00:06]: ... File [modinfo.luc]
# Master: [00:00:06]: ... File [modinfo.lua]
# Master: [00:00:06]: ... File [MineableGems.lua]
# Master: [00:00:06]: ... File [preview.xml]
# Master: [00:00:06]: ... File [preview.tex]
# Master: [00:00:06]: DelDirectory [../mods/workshop-380423963] 0: ok.
# Master: [00:00:06]: cWorkshopMod::UnzipMod ../mods/workshop-380423963
# Master: [00:00:08]: OnDownloadPublishedFile [1] 2229630615
# Caves:  [00:00:08]: OnDownloadPublishedFile [1] 2229630615
# Master: [00:00:09]: OnDownloadPublishedFile [1] 700236083
# Master: [00:00:09]: Could not open directory [../mods/workshop-700236083] 2 (/content/dontstarvetogether_dedicated_server/data)
# Master: [00:00:09]: cWorkshopMod::UnzipMod ../mods/workshop-700236083
# Caves:  [00:00:09]: OnDownloadPublishedFile [1] 700236083
# Caves:  [00:00:09]: ... File [modmain.lua]
# Caves:  [00:00:09]: ... File [modinfo.lua]
# Caves:  [00:00:09]: ... File [preview.pdn]
# Caves:  [00:00:09]: ... Directory [scripts]
# Caves:  [00:00:09]: ... Directory [images]
# Caves:  [00:00:09]: ... File [pickanimations.lua]
# Caves:  [00:00:09]: DelDirectory [../mods/workshop-700236083/scripts] 0: ok.
# Caves:  [00:00:09]: ... File [QuickActions.pdn]
# Caves:  [00:00:09]: ... File [QuickActions.tex]
# Caves:  [00:00:09]: ... File [QuickActions.xml]
# Caves:  [00:00:09]: DelDirectory [../mods/workshop-700236083/images] 0: ok.
# Caves:  [00:00:09]: DelDirectory [../mods/workshop-700236083] 0: ok.
# Caves:  [00:00:09]: cWorkshopMod::UnzipMod ../mods/workshop-700236083
# Master: [00:00:09]: OnDownloadPublishedFile [1] 666155465
# Master: [00:00:09]: Could not open directory [../mods/workshop-666155465] 2 (/content/dontstarvetogether_dedicated_server/data)
# Master: [00:00:09]: cWorkshopMod::UnzipMod ../mods/workshop-666155465
# Caves:  [00:00:09]: OnDownloadPublishedFile [1] 666155465
# Caves:  [00:00:09]: ... File [showme_english_example.lua]
# Caves:  [00:00:09]: ... File [modmain.lua]
# Caves:  [00:00:09]: ... File [showme_cht.lua]
# Caves:  [00:00:09]: ... File [modinfo.lua]
# Caves:  [00:00:09]: ... File [showme_pl.lua]
# Caves:  [00:00:09]: ... File [showme_ru.lua]
# Caves:  [00:00:09]: ... File [showme_chs.lua]
# Caves:  [00:00:09]: ... File [history.txt]
# Caves:  [00:00:09]: ... File [showme_es.lua]
# Caves:  [00:00:09]: ... File [preview.xml]
# Caves:  [00:00:09]: ... File [preview.tex]
# Caves:  [00:00:09]: ... File [showme_kr.lua]
# Caves:  [00:00:09]: ... File [showme_br.lua]
# Caves:  [00:00:09]: DelDirectory [../mods/workshop-666155465] 0: ok.
# Caves:  [00:00:09]: cWorkshopMod::UnzipMod ../mods/workshop-666155465
# Caves:  [00:00:10]: OnDownloadPublishedFile [1] 1207269058
# Master: [00:00:10]: OnDownloadPublishedFile [1] 1207269058
# Caves:  [00:00:11]: OnDownloadPublishedFile [1] 1595631294
# Caves:  [00:00:11]: Could not open directory [../mods/workshop-1595631294] 2 (/content/dontstarvetogether_dedicated_server/data)
# Caves:  [00:00:11]: cWorkshopMod::UnzipMod ../mods/workshop-1595631294
# Master: [00:00:11]: OnDownloadPublishedFile [1] 1595631294
# Master: [00:00:11]: ... File [modmain.lua]
# Master: [00:00:11]: ... File [modicon.xml]
# Master: [00:00:11]: ... File [modinfo.lua]
# Master: [00:00:11]: ... File [modicon.tex]
# Master: [00:00:11]: ... Directory [scripts]
# Master: [00:00:11]: ... Directory [components]
# Master: [00:00:11]: ... File [smart_minisign.lua]
# Master: [00:00:11]: DelDirectory [../mods/workshop-1595631294/scripts/components] 0: ok.
# Master: [00:00:11]: DelDirectory [../mods/workshop-1595631294/scripts] 0: ok.
# Master: [00:00:11]: DelDirectory [../mods/workshop-1595631294] 0: ok.
# Master: [00:00:11]: cWorkshopMod::UnzipMod ../mods/workshop-1595631294
# Caves:  [00:00:11]: OnDownloadPublishedFile [1] 1271089343
# Caves:  [00:00:11]: Could not open directory [../mods/workshop-1271089343] 2 (/content/dontstarvetogether_dedicated_server/data)
# Caves:  [00:00:11]: cWorkshopMod::UnzipMod ../mods/workshop-1271089343
# Master: [00:00:11]: OnDownloadPublishedFile [1] 1271089343
# Master: [00:00:11]: ... File [modmain.lua]
# Master: [00:00:11]: ... File [modicon.xml]
# Master: [00:00:11]: ... File [modinfo.lua]
# Master: [00:00:11]: ... File [modicon.tex]
# Master: [00:00:11]: DelDirectory [../mods/workshop-1271089343] 0: ok.
# Master: [00:00:11]: cWorkshopMod::UnzipMod ../mods/workshop-1271089343
# Caves:  [00:00:12]: OnDownloadPublishedFile [1] 1172839635
# Caves:  [00:00:12]: Could not open directory [../mods/workshop-1172839635] 2 (/content/dontstarvetogether_dedicated_server/data)
# Caves:  [00:00:12]: cWorkshopMod::UnzipMod ../mods/workshop-1172839635
# Master: [00:00:12]: OnDownloadPublishedFile [1] 1172839635
# Master: [00:00:12]: ... File [modmain.lua]
# Master: [00:00:12]: ... File [modicon.xml]
# Master: [00:00:12]: ... File [modinfo.lua]
# Master: [00:00:12]: ... File [modicon.tex]
# Master: [00:00:12]: DelDirectory [../mods/workshop-1172839635] 0: ok.
# Master: [00:00:12]: cWorkshopMod::UnzipMod ../mods/workshop-1172839635
# Caves:  [00:00:12]: OnDownloadPublishedFile [1] 375850593
# Master: [00:00:12]: OnDownloadPublishedFile [1] 375850593
# Caves:  [00:00:12]: Could not open directory [../mods/workshop-375850593] 2 (/content/dontstarvetogether_dedicated_server/data)
# Caves:  [00:00:12]: cWorkshopMod::UnzipMod ../mods/workshop-375850593
# Master: [00:00:12]: DelDirectory [../mods/workshop-375850593] 0: ok.
# Master: [00:00:12]: cWorkshopMod::UnzipMod ../mods/workshop-375850593
# Caves:  [00:00:44]: SUCCESS: Loaded modoverrides.lua
# Caves:  [00:00:44]: modoverrides.lua enabling workshop-374550642
# Caves:  [00:00:44]: modoverrides.lua enabling workshop-1207269058
# Caves:  [00:00:44]: modoverrides.lua enabling workshop-666155465
# Caves:  [00:00:44]: modoverrides.lua enabling workshop-378160973
# Caves:  [00:00:44]: modoverrides.lua enabling workshop-1595631294
# Caves:  [00:00:44]: modoverrides.lua enabling workshop-1530801499
# Caves:  [00:00:44]: ModIndex:GetModsToLoad inserting moddir, 	workshop-1530801499
# Caves:  [00:00:44]: ModIndex:GetModsToLoad inserting moddir, 	workshop-374550642
# Caves:  [00:00:44]: ModIndex:GetModsToLoad inserting moddir, 	workshop-378160973
# Caves:  [00:00:44]: ModIndex:GetModsToLoad inserting moddir, 	workshop-666155465
# Caves:  [00:00:44]: ModIndex:GetModsToLoad inserting moddir, 	workshop-1595631294
# Caves:  [00:00:44]: ModIndex:GetModsToLoad inserting forcedmoddir, 	workshop-1207269058
# Caves:  [00:00:44]: Could not load mod_config_data/modconfiguration_workshop-1530801499_CLIENT
# Caves:  [00:00:44]: Loading mod: workshop-1530801499 (Fast Travel (GUI)) Version:1.06
# Caves:  [00:00:44]: Could not load mod_config_data/modconfiguration_workshop-374550642_CLIENT
# Caves:  [00:00:44]: Loading mod: workshop-374550642 (Increased Stack size) Version:1.62
# Caves:  [00:00:44]: Could not load mod_config_data/modconfiguration_workshop-378160973_CLIENT
# Caves:  [00:00:44]: Loading mod: workshop-378160973 (Global Positions) Version:1.7.3
# Caves:  [00:00:44]: Could not load mod_config_data/modconfiguration_workshop-666155465_CLIENT
# Caves:  [00:00:44]: Loading mod: workshop-666155465 (Show Me (Origin)) Version:0.50
# Caves:  [00:00:44]: Could not load mod_config_data/modconfiguration_workshop-1595631294_CLIENT
# Caves:  [00:00:44]: Loading mod: workshop-1595631294 (Smart Minisign) Version:1.1.5
# Caves:  [00:00:44]: Could not load mod_config_data/modconfiguration_workshop-1207269058_CLIENT
# Caves:  [00:00:44]: Loading mod: workshop-1207269058 ( Simple Health Bar DST) Version:2.15
# Caves:  [00:00:44]: applying configuration_options from modoverrides.lua to mod workshop-374550642
# Caves:  [00:00:44]: Overriding mod workshop-374550642's option MAXSTACKSIZE with value 99
# Caves:  [00:00:44]: applying configuration_options from modoverrides.lua to mod workshop-1207269058
# Caves:  [00:00:44]: applying configuration_options from modoverrides.lua to mod workshop-666155465
# Caves:  [00:00:44]: Overriding mod workshop-666155465's option chestR with value -1
# Caves:  [00:00:44]: Overriding mod workshop-666155465's option food_style with value 0
# Caves:  [00:00:44]: Overriding mod workshop-666155465's option show_uses with value -1
# Caves:  [00:00:44]: Overriding mod workshop-666155465's option show_food_units with value -1
# Caves:  [00:00:44]: Overriding mod workshop-666155465's option lang with value auto
# Caves:  [00:00:44]: Overriding mod workshop-666155465's option chestB with value -1
# Caves:  [00:00:44]: Overriding mod workshop-666155465's option food_order with value 0
# Caves:  [00:00:44]: Overriding mod workshop-666155465's option chestG with value -1
# Caves:  [00:00:44]: Overriding mod workshop-666155465's option food_estimation with value -1
# Caves:  [00:00:44]: applying configuration_options from modoverrides.lua to mod workshop-378160973
# Caves:  [00:00:44]: Overriding mod workshop-378160973's option FIREOPTIONS with value 2
# Caves:  [00:00:44]: Overriding mod workshop-378160973's option SHOWFIREICONS with value true
# Caves:  [00:00:44]: Overriding mod workshop-378160973's option SHAREMINIMAPPROGRESS with value true
# Caves:  [00:00:44]: Overriding mod workshop-378160973's option SHOWPLAYERICONS with value true
# Caves:  [00:00:44]: Overriding mod workshop-378160973's option OVERRIDEMODE with value false
# Caves:  [00:00:44]: Overriding mod workshop-378160973's option SHOWPLAYERSOPTIONS with value 2
# Caves:  [00:00:44]: Overriding mod workshop-378160973's option ENABLEPINGS with value true
# Caves:  [00:00:44]: applying configuration_options from modoverrides.lua to mod workshop-1595631294
# Caves:  [00:00:44]: Overriding mod workshop-1595631294's option SaltBox with value false
# Caves:  [00:00:44]: Overriding mod workshop-1595631294's option BundleItems with value false
# Caves:  [00:00:44]: Overriding mod workshop-1595631294's option Digornot with value false
# Caves:  [00:00:44]: Overriding mod workshop-1595631294's option ChangeSkin with value true
# Caves:  [00:00:44]: Overriding mod workshop-1595631294's option Icebox with value false
# Caves:  [00:00:44]: Overriding mod workshop-1595631294's option DragonflyChest with value false
# Caves:  [00:00:44]: applying configuration_options from modoverrides.lua to mod workshop-1530801499
# Caves:  [00:00:44]: Overriding mod workshop-1530801499's option Ownership with value false
# Caves:  [00:00:44]: Overriding mod workshop-1530801499's option Sanity_Cost with value 1
# Caves:  [00:00:44]: Overriding mod workshop-1530801499's option Hunger_Cost with value 1
# Caves:  [00:00:44]: Mod: workshop-1530801499 (Fast Travel (GUI))	Loading modworldgenmain.lua
# Caves:  [00:00:44]: Mod: workshop-1530801499 (Fast Travel (GUI))	  Mod had no modworldgenmain.lua. Skipping.
# Caves:  [00:00:44]: Mod: workshop-1530801499 (Fast Travel (GUI))	Loading modmain.lua
# Master: [00:00:44]: SUCCESS: Loaded modoverrides.lua
# Master: [00:00:44]: modoverrides.lua enabling workshop-374550642
# Master: [00:00:44]: modoverrides.lua enabling workshop-1207269058
# Master: [00:00:44]: modoverrides.lua enabling workshop-666155465
# Master: [00:00:44]: modoverrides.lua enabling workshop-378160973
# Master: [00:00:44]: modoverrides.lua enabling workshop-1595631294
# Master: [00:00:44]: modoverrides.lua enabling workshop-1530801499
# Master: [00:00:44]: ModIndex:GetModsToLoad inserting moddir, 	workshop-1530801499
# Master: [00:00:44]: ModIndex:GetModsToLoad inserting moddir, 	workshop-374550642
# Master: [00:00:44]: ModIndex:GetModsToLoad inserting moddir, 	workshop-378160973
# Master: [00:00:44]: ModIndex:GetModsToLoad inserting moddir, 	workshop-666155465
# Master: [00:00:44]: ModIndex:GetModsToLoad inserting moddir, 	workshop-1595631294
# Master: [00:00:44]: ModIndex:GetModsToLoad inserting forcedmoddir, 	workshop-1207269058
# Master: [00:00:44]: Could not load mod_config_data/modconfiguration_workshop-1530801499_CLIENT
# Master: [00:00:44]: Loading mod: workshop-1530801499 (Fast Travel (GUI)) Version:1.06
# Master: [00:00:44]: Could not load mod_config_data/modconfiguration_workshop-374550642_CLIENT
# Master: [00:00:44]: Loading mod: workshop-374550642 (Increased Stack size) Version:1.62
# Master: [00:00:44]: Could not load mod_config_data/modconfiguration_workshop-378160973_CLIENT
# Master: [00:00:44]: Loading mod: workshop-378160973 (Global Positions) Version:1.7.3
# Master: [00:00:44]: Could not load mod_config_data/modconfiguration_workshop-666155465_CLIENT
# Master: [00:00:44]: Loading mod: workshop-666155465 (Show Me (Origin)) Version:0.50
# Master: [00:00:44]: Could not load mod_config_data/modconfiguration_workshop-1595631294_CLIENT
# Master: [00:00:44]: Loading mod: workshop-1595631294 (Smart Minisign) Version:1.1.5
# Master: [00:00:44]: Could not load mod_config_data/modconfiguration_workshop-1207269058_CLIENT
# Master: [00:00:44]: Loading mod: workshop-1207269058 ( Simple Health Bar DST) Version:2.15
# Master: [00:00:44]: applying configuration_options from modoverrides.lua to mod workshop-374550642
# Master: [00:00:44]: Overriding mod workshop-374550642's option MAXSTACKSIZE with value 99
# Master: [00:00:44]: applying configuration_options from modoverrides.lua to mod workshop-1207269058
# Master: [00:00:44]: applying configuration_options from modoverrides.lua to mod workshop-666155465
# Master: [00:00:44]: Overriding mod workshop-666155465's option chestR with value -1
# Master: [00:00:44]: Overriding mod workshop-666155465's option food_style with value 0
# Master: [00:00:44]: Overriding mod workshop-666155465's option show_uses with value -1
# Master: [00:00:44]: Overriding mod workshop-666155465's option show_food_units with value -1
# Master: [00:00:44]: Overriding mod workshop-666155465's option lang with value auto
# Master: [00:00:44]: Overriding mod workshop-666155465's option chestB with value -1
# Master: [00:00:44]: Overriding mod workshop-666155465's option food_order with value 0
# Master: [00:00:44]: Overriding mod workshop-666155465's option chestG with value -1
# Master: [00:00:44]: Overriding mod workshop-666155465's option food_estimation with value -1
# Master: [00:00:44]: applying configuration_options from modoverrides.lua to mod workshop-378160973
# Master: [00:00:44]: Overriding mod workshop-378160973's option FIREOPTIONS with value 2
# Master: [00:00:44]: Overriding mod workshop-378160973's option SHOWFIREICONS with value true
# Master: [00:00:44]: Overriding mod workshop-378160973's option SHAREMINIMAPPROGRESS with value true
# Master: [00:00:44]: Overriding mod workshop-378160973's option SHOWPLAYERICONS with value true
# Master: [00:00:44]: Overriding mod workshop-378160973's option OVERRIDEMODE with value false
# Master: [00:00:44]: Overriding mod workshop-378160973's option SHOWPLAYERSOPTIONS with value 2
# Master: [00:00:44]: Overriding mod workshop-378160973's option ENABLEPINGS with value true
# Master: [00:00:44]: applying configuration_options from modoverrides.lua to mod workshop-1595631294
# Master: [00:00:44]: Overriding mod workshop-1595631294's option SaltBox with value false
# Master: [00:00:44]: Overriding mod workshop-1595631294's option BundleItems with value false
# Master: [00:00:44]: Overriding mod workshop-1595631294's option Digornot with value false
# Master: [00:00:44]: Overriding mod workshop-1595631294's option ChangeSkin with value true
# Master: [00:00:44]: Overriding mod workshop-1595631294's option Icebox with value false
# Master: [00:00:44]: Overriding mod workshop-1595631294's option DragonflyChest with value false
# Master: [00:00:44]: applying configuration_options from modoverrides.lua to mod workshop-1530801499
# Master: [00:00:44]: Overriding mod workshop-1530801499's option Ownership with value false
# Master: [00:00:44]: Overriding mod workshop-1530801499's option Sanity_Cost with value 1
# Master: [00:00:44]: Overriding mod workshop-1530801499's option Hunger_Cost with value 1
# Master: [00:00:44]: Mod: workshop-1530801499 (Fast Travel (GUI))	Loading modworldgenmain.lua
# Master: [00:00:44]: Mod: workshop-1530801499 (Fast Travel (GUI))	  Mod had no modworldgenmain.lua. Skipping.
# Master: [00:00:44]: Mod: workshop-1530801499 (Fast Travel (GUI))	Loading modmain.lua
# Caves:  [00:00:44]: Mod: workshop-666155465 (Show Me (Origin))	Loading modworldgenmain.lua
# Caves:  [00:00:44]: Mod: workshop-666155465 (Show Me (Origin))	  Mod had no modworldgenmain.lua. Skipping.
# Master: [00:00:44]: Mod: workshop-666155465 (Show Me (Origin))	Loading modworldgenmain.lua
# Caves:  [00:00:44]: Mod: workshop-666155465 (Show Me (Origin))	Loading modmain.lua
# Master: [00:00:44]: Mod: workshop-666155465 (Show Me (Origin))	  Mod had no modworldgenmain.lua. Skipping.
# Master: [00:00:44]: Mod: workshop-666155465 (Show Me (Origin))	Loading modmain.lua
# Master: [00:00:44]: ShowMe version:	0.50
# Master: [00:00:44]: show_food_units	-1	-1	-1
# Master: [00:00:44]: show_uses	-1	-1	-1
# Master: [00:00:44]: Mod: workshop-374550642 (Increased Stack size)	Loading modworldgenmain.lua
# Master: [00:00:44]: Mod: workshop-374550642 (Increased Stack size)	  Mod had no modworldgenmain.lua. Skipping.
# Master: [00:00:44]: Mod: workshop-374550642 (Increased Stack size)	Loading modmain.lua
# Caves:  [00:00:44]: ShowMe version:	0.50
# Caves:  [00:00:44]: show_food_units	-1	-1	-1
# Caves:  [00:00:44]: show_uses	-1	-1	-1
# Caves:  [00:00:44]: Mod: workshop-374550642 (Increased Stack size)	Loading modworldgenmain.lua
# Master: [00:00:44]: Mod: workshop-378160973 (Global Positions)	Loading modworldgenmain.lua
# Caves:  [00:00:44]: Mod: workshop-374550642 (Increased Stack size)	  Mod had no modworldgenmain.lua. Skipping.
# Master: [00:00:44]: Mod: workshop-378160973 (Global Positions)	  Mod had no modworldgenmain.lua. Skipping.
# Caves:  [00:00:44]: Mod: workshop-374550642 (Increased Stack size)	Loading modmain.lua
# Master: [00:00:44]: Mod: workshop-378160973 (Global Positions)	Loading modmain.lua
# Caves:  [00:00:44]: Mod: workshop-378160973 (Global Positions)	Loading modworldgenmain.lua
# Caves:  [00:00:44]: Mod: workshop-378160973 (Global Positions)	  Mod had no modworldgenmain.lua. Skipping.
# Master: [00:00:44]: ModIndex:GetModsToLoad inserting moddir, 	workshop-1530801499
# Master: [00:00:44]: ModIndex:GetModsToLoad inserting moddir, 	workshop-374550642
# Master: [00:00:44]: ModIndex:GetModsToLoad inserting moddir, 	workshop-378160973
# Master: [00:00:44]: ModIndex:GetModsToLoad inserting moddir, 	workshop-666155465
# Master: [00:00:44]: ModIndex:GetModsToLoad inserting moddir, 	workshop-1595631294
# Master: [00:00:44]: ModIndex:GetModsToLoad inserting forcedmoddir, 	workshop-1207269058
# Caves:  [00:00:44]: Mod: workshop-378160973 (Global Positions)	Loading modmain.lua
# Master: [00:00:44]: Mod: workshop-1595631294 (Smart Minisign)	Loading modworldgenmain.lua
# Master: [00:00:44]: Mod: workshop-1595631294 (Smart Minisign)	  Mod had no modworldgenmain.lua. Skipping.
# Master: [00:00:44]: Mod: workshop-1595631294 (Smart Minisign)	Loading modmain.lua
# Master: [00:00:44]: Mod: workshop-1207269058 ( Simple Health Bar DST)	Loading modworldgenmain.lua
# Master: [00:00:44]: Mod: workshop-1207269058 ( Simple Health Bar DST)	  Mod had no modworldgenmain.lua. Skipping.
# Master: [00:00:44]: Mod: workshop-1207269058 ( Simple Health Bar DST)	Loading modmain.lua
# Caves:  [00:00:44]: ModIndex:GetModsToLoad inserting moddir, 	workshop-1530801499
# Caves:  [00:00:44]: ModIndex:GetModsToLoad inserting moddir, 	workshop-374550642
# Caves:  [00:00:44]: ModIndex:GetModsToLoad inserting moddir, 	workshop-378160973
# Caves:  [00:00:44]: ModIndex:GetModsToLoad inserting moddir, 	workshop-666155465
# Caves:  [00:00:44]: ModIndex:GetModsToLoad inserting moddir, 	workshop-1595631294
# ...
# Caves:  [00:01:10]: setting 	isalterawake	false
# Caves:  [00:01:10]: setting 	isnightmarecalm	false
# Caves:  [00:01:10]: setting 	isnight	true
# Caves:  [00:01:10]: setting 	isdusk	false
# Caves:  [00:01:10]: setting 	isspring	false
# Caves:  [00:01:10]: setting 	isautumn	false
# Caves:  [00:01:10]: setting 	issnowing	false
# Caves:  [00:01:10]: setting 	iswaxingmoon	true
# Caves:  [00:01:10]: setting 	phase	night
# Caves:  [00:01:10]: setting 	snowlevel	0
# Caves:  [00:01:10]: setting 	issnowcovered	false
# Caves:  [00:01:10]: setting 	autumnlength	20
# Caves:  [00:01:10]: setting 	pop	0.28776464272152
# Caves:  [00:01:10]: setting 	nightmaretime	521.05346906215
# Caves:  [00:01:10]: setting 	seasonprogress	0.53333333333333
# Caves:  [00:01:10]: setting 	moonphase	new
# Caves:  [00:01:10]: setting 	nightmarephase	wild
# Caves:  [00:01:10]: setting 	cycles	553
# Caves:  [00:01:10]: setting 	timeinphase	0.14064691716974
# Caves:  [00:01:10]: setting 	iscavenight	false
# Caves:  [00:01:10]: setting 	iscavenewmoon	false
# Caves:  [00:01:10]: setting 	issummer	true
# Caves:  [00:01:10]: setting 	temperature	56.9808813357
# Caves:  [00:01:10]: setting 	time	0.096694755554199
# Caves:  [00:01:10]: [Shard] Secondary shard is waiting for LUA...
# Caves:  [00:01:18]: SWITCHING 	false
# Caves:  [00:01:18]: Reconstructing topology
# Caves:  [00:01:18]: 	...Sorting points
# Caves:  [00:01:18]: 	...Sorting edges
# Caves:  [00:01:18]: 	...Connecting nodes
# Caves:  [00:01:18]: 	...Validating connections
# Caves:  [00:01:18]: 	...Housekeeping
# Caves:  [00:01:18]: 	...Done!
# Caves:  [00:01:18]: 1 uploads added to server. From server_temp
# Caves:  [00:01:18]: About to start a shard with these settings:
# Caves:  [00:01:18]:   ShardName: Caves
# Caves:  [00:01:18]:   ShardID: 3968497828
# Caves:  [00:01:18]:   ShardRole: SECONDARY
# Caves:  [00:01:18]:   MasterHost: 127.0.0.1
# Caves:  [00:01:18]:   MasterBind: (null)
# Caves:  [00:01:18]:   MasterPort: 10888
# Caves:  [00:01:18]: [Shard] Connecting to master...
# Caves:  [00:01:18]: Telling Client our new session identifier: 1B555A53FF70A70C
# Caves:  [00:01:19]: Check for write access: TRUE
# Caves:  [00:01:19]: Check for read access: TRUE
# Caves:  [00:01:19]: Available disk space for save files: 13435 MB
# Caves:  [00:01:19]: ModIndex: Load sequence finished successfully.
# Master: [00:01:19]: Reconstructing topology
# Master: [00:01:19]: 	...Sorting points
# Master: [00:01:19]: 	...Sorting edges
# Master: [00:01:19]: 	...Connecting nodes
# Master: [00:01:19]: 	...Validating connections
# Caves:  [00:01:19]: Reset() returning
# Caves:  [00:01:19]: [Shard] Connection to master failed. Waiting to reconnect...
# Master: [00:01:19]: 	...Housekeeping
# Master: [00:01:19]: 	...Done!
# Caves:  [00:01:20]: Validating portal[3] <-> 1[3] (inactive)
# Caves:  [00:01:20]: Validating portal[7] <-> 1[7] (inactive)
# Master: [00:01:20]: 1 uploads added to server. From server_temp
# Master: [00:01:20]: About to start a shard with these settings:
# Master: [00:01:20]:   ShardName: [SHDMASTER]
# Master: [00:01:20]:   ShardID: 1
# Master: [00:01:20]:   ShardRole: MASTER
# Master: [00:01:20]:   MasterHost: (null)
# Master: [00:01:20]:   MasterBind: 127.0.0.1
# Master: [00:01:20]:   MasterPort: 10888
# Master: [00:01:20]: [Shard] Starting master server
# Caves:  [00:01:20]: Validating portal[9] <-> 1[9] (inactive)
# Caves:  [00:01:20]: Validating portal[2] <-> 1[2] (inactive)
# Master: [00:01:20]: [Shard] Shard server started on port: 10888
# Master: [00:01:20]: Telling Client our new session identifier: 0E72137FA1E33DDA
# Caves:  [00:01:20]: Validating portal[1] <-> 1[1] (inactive)
# Caves:  [00:01:20]: Validating portal[10] <-> 1[10] (inactive)
# Caves:  [00:01:20]: Validating portal[4] <-> 1[4] (inactive)
# Caves:  [00:01:20]: Validating portal[5] <-> 1[5] (inactive)
# Caves:  [00:01:20]: Validating portal[8] <-> 1[8] (inactive)
# Caves:  [00:01:20]: Validating portal[6] <-> 1[6] (inactive)
# Master: [00:01:20]: Check for write access: TRUE
# Master: [00:01:20]: Check for read access: TRUE
# Master: [00:01:20]: Available disk space for save files: 13435 MB
# Master: [00:01:20]: ModIndex: Load sequence finished successfully.
# Master: [00:01:23]: Reset() returning
# Master: [00:01:24]: Validating portal[4] <-> 3968497828[4] (inactive)
# Master: [00:01:24]: Validating portal[9] <-> 3968497828[9] (inactive)
# Master: [00:01:24]: Validating portal[5] <-> 3968497828[5] (inactive)
# Master: [00:01:24]: Validating portal[6] <-> 3968497828[6] (inactive)
# Master: [00:01:24]: Validating portal[8] <-> 3968497828[8] (inactive)
# Master: [00:01:24]: Validating portal[7] <-> 3968497828[7] (inactive)
# Master: [00:01:24]: Validating portal[10] <-> 3968497828[10] (inactive)
# Master: [00:01:24]: Validating portal[1] <-> 3968497828[1] (inactive)
# Caves:  [00:01:24]: About to start a shard with these settings:
# Caves:  [00:01:24]:   ShardName: Caves
# Caves:  [00:01:24]:   ShardID: 3968497828
# Caves:  [00:01:24]:   ShardRole: SECONDARY
# Caves:  [00:01:24]:   MasterHost: 127.0.0.1
# Caves:  [00:01:24]:   MasterBind: (null)
# Caves:  [00:01:24]:   MasterPort: 10888
# Master: [00:01:24]: Validating portal[3] <-> 3968497828[3] (inactive)
# Caves:  [00:01:24]: [Shard] Connecting to master...
# Caves:  [00:01:24]: [Shard] Sending secondary shard information to master...
# Master: [00:01:24]: Validating portal[2] <-> 3968497828[2] (inactive)
# Master: [00:01:25]: Could not find anim build FROMNUM
# Master: [00:01:25]: Could not find anim build FROMNUM
# Master: [00:01:25]: Could not find anim build FROMNUM
# Master: [00:01:25]: Could not find anim build FROMNUM
# Master: [00:01:25]: Could not find anim build FROMNUM
# Master: [00:01:25]: Could not find anim build FROMNUM
# Master: [00:01:25]: Could not find anim build FROMNUM
# Master: [00:01:25]: Could not find anim build FROMNUM
# Master: [00:01:25]: Could not find anim build FROMNUM
# Master: [00:01:25]: Could not find anim build FROMNUM
# Master: [00:01:25]: Could not find anim build FROMNUM
# Master: [00:01:25]: Could not find anim build FROMNUM
# Master: [00:01:25]: Could not find anim build FROMNUM
# Master: [00:01:25]: Could not find anim build FROMNUM
# Master: [00:01:25]: Could not find anim build FROMNUM
# Master: [00:01:25]: Could not find anim build FROMNUM
# Master: [00:01:25]: Could not find anim build FROMNUM
# Master: [00:01:25]: Could not find anim build FROMNUM
# Master: [00:01:25]: Could not find anim build FROMNUM
# Master: [00:01:25]: Sim paused
# Master: [00:01:28]: OnDownloadPublishedFile [1] 1505270912
# Master: [00:01:28]: Best lobby region is aws/US (ping 38)
# Master: [00:01:28]: Registering master server in US lobby
# Master: [00:01:29]: [Shard] Secondary shar Caves(3968497828) connected: [LAN] 127.0.0.1
# Caves:  [00:01:29]: Overriding region to US
# Caves:  [00:01:29]: Registering secondary shard in US lobby
# Master: [00:01:29]: OnDownloadPublishedFile [1] 336882447
# Master: [00:01:29]: Could not open directory [../mods/workshop-336882447] 2 (/content/dontstarvetogether_dedicated_server/data)
# Master: [00:01:29]: cWorkshopMod::UnzipMod ../mods/workshop-336882447
# Caves:  [00:01:29]: OnDownloadPublishedFile [1] 1505270912
# Caves:  [00:01:29]: [Shard] secondary shard is now ready!
# Master: [00:01:29]: [Shard] Secondary Caves(3968497828) ready!
# Master: [00:01:29]: World 3968497828 is now connected
# Master: [00:01:29]: Validating portal[4] <-> 3968497828[4] (disabled)
# Master: [00:01:29]: Validating portal[9] <-> 3968497828[9] (disabled)
# Master: [00:01:29]: Validating portal[5] <-> 3968497828[5] (active)
# Master: [00:01:29]: Validating portal[6] <-> 3968497828[6] (disabled)
# Master: [00:01:29]: Validating portal[8] <-> 3968497828[8] (disabled)
# Master: [00:01:29]: Validating portal[7] <-> 3968497828[7] (disabled)
# Master: [00:01:29]: Validating portal[10] <-> 3968497828[10] (active)
# Master: [00:01:29]: Validating portal[1] <-> 3968497828[1] (active)
# Master: [00:01:29]: Validating portal[3] <-> 3968497828[3] (active)
# Master: [00:01:29]: Validating portal[2] <-> 3968497828[2] (disabled)
# Caves:  [00:01:29]: World 1 is now connected
# Caves:  [00:01:29]: Validating portal[3] <-> 1[3] (active)
# Caves:  [00:01:29]: Validating portal[7] <-> 1[7] (active)
# Caves:  [00:01:29]: Validating portal[9] <-> 1[9] (active)
# Caves:  [00:01:29]: Validating portal[2] <-> 1[2] (active)
# Caves:  [00:01:29]: Validating portal[1] <-> 1[1] (active)
# Caves:  [00:01:29]: Validating portal[10] <-> 1[10] (active)
# Caves:  [00:01:29]: Validating portal[4] <-> 1[4] (active)
# Caves:  [00:01:29]: Validating portal[5] <-> 1[5] (active)
# Caves:  [00:01:29]: Validating portal[8] <-> 1[8] (active)
# Caves:  [00:01:29]: Validating portal[6] <-> 1[6] (active)
# Master: [00:01:29]: OnDownloadPublishedFile [1] 344071294
# Master: [00:01:29]: Could not open directory [../mods/workshop-344071294] 2 (/content/dontstarvetogether_dedicated_server/data)
# Master: [00:01:29]: cWorkshopMod::UnzipMod ../mods/workshop-344071294
# Caves:  [00:01:29]: OnDownloadPublishedFile [1] 336882447
# Caves:  [00:01:29]: ... File [modmain.lua]
# Caves:  [00:01:29]: ... File [modicon.xml]
# Caves:  [00:01:29]: ... File [modinfo.lua]
# Caves:  [00:01:29]: ... File [modicon.tex]
# Caves:  [00:01:29]: ... Directory [scripts]
# Caves:  [00:01:29]: ... Directory [components]
# Caves:  [00:01:29]: ... File [HeartBeat.lua]
# Caves:  [00:01:29]: DelDirectory [../mods/workshop-336882447/scripts/components] 0: ok.
# Caves:  [00:01:29]: DelDirectory [../mods/workshop-336882447/scripts] 0: ok.
# Caves:  [00:01:29]: DelDirectory [../mods/workshop-336882447] 0: ok.
# Caves:  [00:01:29]: cWorkshopMod::UnzipMod ../mods/workshop-336882447
# Caves:  [00:01:30]: OnDownloadPublishedFile [1] 344071294
# Caves:  [00:01:30]: ... File [modmain.lua]
# Caves:  [00:01:30]: ... File [modicon.xml]
# Caves:  [00:01:30]: ... File [modinfo.lua]
# Caves:  [00:01:30]: ... File [modicon.tex]
# Caves:  [00:01:30]: DelDirectory [../mods/workshop-344071294] 0: ok.
# Caves:  [00:01:30]: cWorkshopMod::UnzipMod ../mods/workshop-344071294
# Master: [00:01:30]: OnDownloadPublishedFile [1] 346479579
# Master: [00:01:30]: Could not open directory [../mods/workshop-346479579] 2 (/content/dontstarvetogether_dedicated_server/data)
# Master: [00:01:30]: cWorkshopMod::UnzipMod ../mods/workshop-346479579
# Caves:  [00:01:30]: OnDownloadPublishedFile [1] 346479579
# Caves:  [00:01:30]: ... File [modmain.lua]
# Caves:  [00:01:30]: ... File [modicon.xml]
# Caves:  [00:01:30]: ... File [preview.jpg]
# Caves:  [00:01:30]: ... File [modinfo.lua]
# Caves:  [00:01:30]: ... File [modicon.tex]
# Caves:  [00:01:30]: ... File [modicon.png]
# Caves:  [00:01:30]: DelDirectory [../mods/workshop-346479579] 0: ok.
# Caves:  [00:01:30]: cWorkshopMod::UnzipMod ../mods/workshop-346479579
# Caves:  [00:01:30]: [Shard] secondary shard LUA is now ready!
# Caves:  [00:01:30]: Sim paused
# Master: [00:01:30]: OnDownloadPublishedFile [1] 350811795
# Master: [00:01:30]: Could not open directory [../mods/workshop-350811795] 2 (/content/dontstarvetogether_dedicated_server/data)
# Master: [00:01:30]: cWorkshopMod::UnzipMod ../mods/workshop-350811795
# Caves:  [00:01:30]: OnDownloadPublishedFile [1] 350811795
# Caves:  [00:01:30]: ... File [modmain.lua]
# Caves:  [00:01:30]: ... File [modicon.xml]
# Caves:  [00:01:30]: ... File [modinfo.lua]
# Caves:  [00:01:30]: ... File [modicon.tex]
# Caves:  [00:01:30]: ... Directory [exported]
# Caves:  [00:01:30]: ... Directory [scripts]
# Caves:  [00:01:30]: ... Directory [anim]
# Caves:  [00:01:30]: ... Directory [images]
# Caves:  [00:01:30]: ... Directory [myprefab]
# Caves:  [00:01:30]: ... File [bindingring_build.zip]
# Caves:  [00:01:30]: ... File [bindingring_build.scml.txt]
# Caves:  [00:01:30]: DelDirectory [../mods/workshop-350811795/exported/myprefab] 0: ok.
# Caves:  [00:01:30]: DelDirectory [../mods/workshop-350811795/exported] 0: ok.
# Caves:  [00:01:30]: ... Directory [prefabs]
# Caves:  [00:01:30]: ... Directory [components]
# Caves:  [00:01:30]: ... File [bindingringprefabdef.lua]
# Caves:  [00:01:30]: DelDirectory [../mods/workshop-350811795/scripts/prefabs] 0: ok.
# Caves:  [00:01:30]: ... File [soulteleporter.lua]
# Caves:  [00:01:30]: DelDirectory [../mods/workshop-350811795/scripts/components] 0: ok.
# Caves:  [00:01:30]: DelDirectory [../mods/workshop-350811795/scripts] 0: ok.
# Caves:  [00:01:30]: ... File [bindingring_build.zip]
# Caves:  [00:01:30]: DelDirectory [../mods/workshop-350811795/anim] 0: ok.
# Caves:  [00:01:30]: ... Directory [inventoryimages]
# Caves:  [00:01:30]: ... File [bindingring.tex]
# Caves:  [00:01:30]: ... File [bindingring.xml]
# Caves:  [00:01:30]: DelDirectory [../mods/workshop-350811795/images/inventoryimages] 0: ok.
# Caves:  [00:01:30]: DelDirectory [../mods/workshop-350811795/images] 0: ok.
# Caves:  [00:01:30]: DelDirectory [../mods/workshop-350811795] 0: ok.
# Caves:  [00:01:30]: cWorkshopMod::UnzipMod ../mods/workshop-350811795
# Master: [00:01:31]: OnDownloadPublishedFile [1] 353875384
# Master: [00:01:31]: Could not open directory [../mods/workshop-353875384] 2 (/content/dontstarvetogether_dedicated_server/data)
# Master: [00:01:31]: cWorkshopMod::UnzipMod ../mods/workshop-353875384
# Caves:  [00:01:31]: OnDownloadPublishedFile [1] 353875384
# Caves:  [00:01:31]: ... File [modmain.lua]
# Caves:  [00:01:31]: ... File [modicon.xml]
# Caves:  [00:01:31]: ... File [preview.jpg]
# Caves:  [00:01:31]: ... File [modinfo.lua]
# Caves:  [00:01:31]: ... File [modicon.tex]
# Caves:  [00:01:31]: ... File [modicon.png]
# Caves:  [00:01:31]: DelDirectory [../mods/workshop-353875384] 0: ok.
# Caves:  [00:01:31]: cWorkshopMod::UnzipMod ../mods/workshop-353875384
# Master: [00:01:32]: OnDownloadPublishedFile [1] 361336115
# Master: [00:01:32]: Could not open directory [../mods/workshop-361336115] 2 (/content/dontstarvetogether_dedicated_server/data)
# Master: [00:01:32]: cWorkshopMod::UnzipMod ../mods/workshop-361336115
# Caves:  [00:01:32]: OnDownloadPublishedFile [1] 361336115
# Caves:  [00:01:32]: ... File [modmain.lua]
# Caves:  [00:01:32]: ... File [modicon.xml]
# Caves:  [00:01:32]: ... File [modinfo.lua]
# Caves:  [00:01:32]: ... File [modicon.tex]
# Caves:  [00:01:32]: ... Directory [scripts]
# Caves:  [00:01:32]: ... Directory [components]
# Caves:  [00:01:32]: ... Directory [screens]
# Caves:  [00:01:32]: ... File [HuntGameLogic.lua]
# Caves:  [00:01:32]: DelDirectory [../mods/workshop-361336115/scripts/components] 0: ok.
# Caves:  [00:01:32]: ... File [huntoverdialog.lua]
# Caves:  [00:01:32]: DelDirectory [../mods/workshop-361336115/scripts/screens] 0: ok.
# Caves:  [00:01:32]: DelDirectory [../mods/workshop-361336115/scripts] 0: ok.
# Caves:  [00:01:32]: DelDirectory [../mods/workshop-361336115] 0: ok.
# Caves:  [00:01:32]: cWorkshopMod::UnzipMod ../mods/workshop-361336115
# Master: [00:01:38]: Registering master server in US lobby
# Caves:  [00:06:29]: Registering secondary shard in US lobby
# Caves:  Updates 0Seconds elapsed: 555.674 fps:0
# Caves:  Saving Dedicated server data...
# Caves:  [00:09:16]: Available disk space for save files: 13434 MB
# Caves:  [00:09:17]: Serializing world: session/1B555A53FF70A70C/0000000614
# Caves:  [00:09:17]: Truncating to snapshot #614...
# Caves:  [00:09:17]:  - session/1B555A53FF70A70C/0000000608
# Caves:  [00:09:17]:    1 file(s) removed
# Caves:  [00:09:17]: [Shard] Stopping shard mode
# Caves:  [00:09:17]: [Steam] SendUserDisconnect for ''
# Caves:  [00:09:18]: Collecting garbage...
# Caves:  [00:09:18]: lua_gc took 0.33 seconds
# Caves:  [00:09:18]: ~ShardLuaProxy()
# Caves:  [00:09:18]: ~cEventLeaderboardProxy()
# Caves:  [00:09:18]: ~ItemServerLuaProxy()
# Caves:  [00:09:18]: ~InventoryLuaProxy()
# Caves:  [00:09:18]: ~NetworkLuaProxy()
# Caves:  [00:09:18]: ~SimLuaProxy()
# Caves:  [00:09:18]: lua_close took 0.40 seconds
# Caves:  [00:09:19]: Could not unload undefined prefab (oceantree_roots_medium)
# Caves:  [00:09:19]: Could not unload undefined prefab (driftwood)
# Caves:  [00:09:19]: Could not unload undefined prefab (alterguardian_spiketrail_fx)
# Caves:  [00:09:19]: Orphaned unnamed resource. This resource must have used Add( resource ) to insert itself into the manager.
# Caves:  [00:09:19]: CurlRequestManager::ClientThread::Main() complete
# Caves:  [00:09:19]: HttpClient2 discarded 0 callbacks.
# Caves:  [00:09:19]: Shutting down

# %% [markdown]
# If you want to stop this dedicated server, just go to the toolbar, find `Runtime` option, and click `Interrupt execute`.

# %% [markdown]
# ## Backup save game (IF NEEDED)

# %% [markdown]
# **You need to backup ur server files unless you mount and use a PR_DIR inside ur drive.**

# %% [markdown]
# Goo, download your ServerBackup.zip, Done.
#
# Yah I will auto download for you.

# %%
# %cd ~/.klei/DoNotStarveTogether
# !zip -r ServerBackup.zip MyDediServer
from google.colab import files
files.download('ServerBackup.zip')
